# %%
# %matplotlib inline

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import random

# %%
#loading file 
SAT_data = "Brett_Resources/SAT_scores.csv"

#Reading the files 
SAT_df = pd.read_csv(SAT_data)

SAT_df.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
SAT_df = SAT_df.drop(['EBRW', 'Math', 'Participation Rate'], axis=1)
SAT_df.head()
# Out:
#         State  Total
# 0     Alabama   1143
# 1      Alaska   1097
# 2     Arizona   1134
# 3    Arkansas   1141
# 4  California   1065

# %%
Crime_data ="Resources - Christin/estimated_crimes.csv"

#Reading the files 
Crime_df = pd.read_csv(Crime_data)

Crime_df.head()
# Out:
#    YEAR               State  population  violent_crime  homicide  rape_legacy  \
# 0  1979  National Statistic   220099000        1208030     21460      76390.0
# 1  1980  National Statistic   225349264        1344520     23040      82990.0
# 2  1981  National Statistic   229465714        1361820     22520      82500.0
# 3  1982  National Statistic   231664458        1322390     21010      78770.0
# 4  1983  National Statistic   233791994        1258087     19308      78918.0
#
#    rape_revised  robbery  aggravated_assault  property_crime  burglary  \
# 0           NaN   480700              629480        11041500   3327700
# 1           NaN   565840              672650        12063700   3795200
# 2           NaN   592910              663900        12061900   3779700
# 3           NaN   553130              669480        11652000   3447100
# 4           NaN   506567              653294        10850543   3129851
#
#    larceny  motor_vehicle_theft caveats
# ...

# %%
Crime_df['Total Crime']=Crime_df['violent_crime']+Crime_df['homicide']+Crime_df['rape_legacy']+Crime_df['rape_revised']+Crime_df['robbery']\
+Crime_df['aggravated_assault']+Crime_df['property_crime']+Crime_df['burglary']+Crime_df['larceny']+Crime_df['motor_vehicle_theft']

Crime_df.head()
# Out:
#    YEAR               State  population  violent_crime  homicide  rape_legacy  \
# 0  1979  National Statistic   220099000        1208030     21460      76390.0
# 1  1980  National Statistic   225349264        1344520     23040      82990.0
# 2  1981  National Statistic   229465714        1361820     22520      82500.0
# 3  1982  National Statistic   231664458        1322390     21010      78770.0
# 4  1983  National Statistic   233791994        1258087     19308      78918.0
#
#    rape_revised  robbery  aggravated_assault  property_crime  burglary  \
# 0           NaN   480700              629480        11041500   3327700
# 1           NaN   565840              672650        12063700   3795200
# 2           NaN   592910              663900        12061900   3779700
# 3           NaN   553130              669480        11652000   3447100
# 4           NaN   506567              653294        10850543   3129851
#
#    larceny  motor_vehicle_theft caveats  Total Crime
# ...

# %%
year_2015 = Crime_df['YEAR']==2015
data_2015 = Crime_df[year_2015]   
data_2015
# Out:
#       YEAR               State  population  violent_crime  homicide  \
# 36    2015  National Statistic   320896618        1199310     15883
# 74    2015                  AK      737709           5391        59
# 114   2015                  AL     4853875          22957       348
# 154   2015                  AR     2977853          15769       189
# 194   2015                  AZ     6817565          27968       306
# 234   2015                  CA    38993940         166883      1861
# 274   2015                  CO     5448819          17348       173
# 314   2015                  CT     3584730           7938       116
# 354   2015                  DC      670377           8538       162
# 394   2015                  DE      944076           4760        62
# 434   2015                  FL    20244914          93625      1041
# 474   2015                  GA    10199398          38891       622
# 514   2015                  HI     1431603           4201        19
# ...

# %%
data_2015 = data_2015.drop(['population','caveats','violent_crime'], axis=1)
data_2015.head()
# Out:
#      YEAR               State  homicide  rape_legacy  rape_revised  robbery  \
# 36   2015  National Statistic     15883      91261.0      126134.0   328109
# 74   2015                  AK        59        648.0         900.0      761
# 114  2015                  AL       348       1449.0        2037.0     4612
# 154  2015                  AR       189       1425.0        2008.0     2117
# 194  2015                  AZ       306       2268.0        3109.0     6360
#
#      aggravated_assault  property_crime  burglary  larceny  \
# 36               764057         8024115   1587564  5723488
# 74                 3671           20806      3511    15249
# 114               15960          144785     35265    99182
# 154               11455           97391     22851    68720
# 194               18193          207184     38010   152388
#
#      motor_vehicle_theft  Total Crime
# 36                713063   18572984.0
# 74                  2046      53042.0
# ...

# %%
fin_crimedata_2015 = data_2015.drop(['homicide','rape_legacy','rape_revised','robbery','aggravated_assault',\
                            'property_crime','burglary','larceny','motor_vehicle_theft','YEAR'], axis=1)
fin_crimedata_2015.head()
# Out:
#                   State  Total Crime
# 36   National Statistic   18572984.0
# 74                   AK      53042.0
# 114                  AL     336933.0
# 154                  AR     227745.0
# 194                  AZ     472572.0

# %%
state_dict= {

    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
SAT_df_fin = SAT_df.replace({"State": state_dict})

# %%
SAT_df_fin.head()
# Out:
#   State  Total
# 0    AL   1143
# 1    AK   1097
# 2    AZ   1134
# 3    AR   1141
# 4    CA   1065

# %%
merge_table = pd.merge(SAT_df_fin, fin_crimedata_2015, on="State", how="outer")
merge_table.head()
# Out:
#   State   Total  Total Crime
# 0    AL  1143.0     336933.0
# 1    AK  1097.0      53042.0
# 2    AZ  1134.0     472572.0
# 3    AR  1141.0     227745.0
# 4    CA  1065.0    2392935.0

# %%
merge_table.rename(columns={'Total': 'Average SAT Score', 'Total Crime':'Crime Rate'}, inplace=True)
merge_table.head()
# Out:
#   State  Average SAT Score  Crime Rate
# 0    AL             1143.0    336933.0
# 1    AK             1097.0     53042.0
# 2    AZ             1134.0    472572.0
# 3    AR             1141.0    227745.0
# 4    CA             1065.0   2392935.0

# %%
# The maximum x value for our chart will be 100
x_limit = 100

# List of values from 0 to 100 each value being 1 greater than the last
x_axis = np.arange(0, x_limit, 1)

# Create a random array of data that we will use for our y values
data = [random.random() for value in x_axis]

# %%
plt.scatter(x_axis, data, marker="o", facecolors="red",alpha=.75)

# %%
print("After looking at a scatter plot comparing the average SAT score per state and the crime rate per capita per state, \nwe can see that there is no apparent correlation.")
# Out:
# After looking at a scatter plot comparing the average SAT score per state and the crime rate per capita per state,
# we can see that there is no apparent correlation.
