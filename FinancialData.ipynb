# %%
#import my modules
import pandas as pd
import numpy as np

financialsCSV = "Brett_Resources/finance_states.csv" 
finance_data = pd.read_csv(financialsCSV)

# %%
finance_data
# Out:
#              PRIMARY_KEY          STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992        NaN        2678885
# 1            1992_ALASKA         ALASKA  1992        NaN        1049591
# 2           1992_ARIZONA        ARIZONA  1992        NaN        3258079
# 3          1992_ARKANSAS       ARKANSAS  1992        NaN        1711959
# 4        1992_CALIFORNIA     CALIFORNIA  1992        NaN       26260025
# ...                  ...            ...   ...        ...            ...
# 1270       2016_VIRGINIA       VIRGINIA  2016  1283493.0       16259274
# 1271     2016_WASHINGTON     WASHINGTON  2016  1083973.0       14964364
# 1272  2016_WEST_VIRGINIA  WEST_VIRGINIA  2016   276764.0        3391579
# 1273      2016_WISCONSIN      WISCONSIN  2016   857736.0       11697466
# 1274        2016_WYOMING        WYOMING  2016    94511.0        2044669
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
#usuing iloc to fins the relavent information for 2015
finance_data.iloc[1175:1226,[1,2,8,9,10,11]]
# Out:
#                      STATE  YEAR  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 1175               ARIZONA  2015            7902600                  3846357
# 1176              ARKANSAS  2015            5350543                  2620399
# 1177            CALIFORNIA  2015           78365958                 38951948
# 1178              COLORADO  2015            9557682                  4578938
# 1179           CONNECTICUT  2015           10542667                  6006275
# 1180              DELAWARE  2015            1975093                  1072395
# 1181  DISTRICT_OF_COLUMBIA  2015            1360942                   557345
# 1182               FLORIDA  2015           27277049                 14931173
# 1183               GEORGIA  2015           18501103                 10081483
# 1184                HAWAII  2015            2521004                  1377713
# 1185                 IDAHO  2015            2029520                  1130814
# ...
