# %%
import pandas as pd
import numpy as np

# %%
file='Resources - Christin/estimated_crimes_1979_2018.csv'
crime_rates = pd.read_csv(file)
crime_rates.head()
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 0  1979        NaN   220099000        1208030     21460      76390.0
# 1  1980        NaN   225349264        1344520     23040      82990.0
# 2  1981        NaN   229465714        1361820     22520      82500.0
# 3  1982        NaN   231664458        1322390     21010      78770.0
# 4  1983        NaN   233791994        1258087     19308      78918.0
#
#    rape_revised  robbery  aggravated_assault  property_crime  burglary  \
# 0           NaN   480700              629480        11041500   3327700
# 1           NaN   565840              672650        12063700   3795200
# 2           NaN   592910              663900        12061900   3779700
# 3           NaN   553130              669480        11652000   3447100
# 4           NaN   506567              653294        10850543   3129851
#
#    larceny  motor_vehicle_theft caveats
# 0  6601000              1112800     NaN
# 1  7136900              1131700     NaN
# ...

# %%
df.columns
# Out:
# Index(['year', 'state_abbr', 'population', 'violent_crime', 'homicide',
#        'rape_legacy', 'rape_revised', 'robbery', 'aggravated_assault',
#        'property_crime', 'burglary', 'larceny', 'motor_vehicle_theft',
#        'caveats'],
#       dtype='object')

# %%
condensed_crime_stats = df.loc[:, ['year', 'state_abbr', 'population', 'violent_crime', 'homicide',
       'rape_legacy', 'rape_revised', 'robbery', 'aggravated_assault',
      'property_crime', 'burglary', 'larceny', 'motor_vehicle_theft']]
condensed_crime_stats
# Out:
#       year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 0     1979        NaN   220099000        1208030     21460      76390.0
# 1     1980        NaN   225349264        1344520     23040      82990.0
# 2     1981        NaN   229465714        1361820     22520      82500.0
# 3     1982        NaN   231664458        1322390     21010      78770.0
# 4     1983        NaN   233791994        1258087     19308      78918.0
# ...    ...        ...         ...            ...       ...          ...
# 2059  2016         WY      584910           1431        20        205.0
# 2060  2017         WY      578934           1358        14          NaN
# 2061  2018         WY      577737           1226        13          NaN
# 2062  2017        NaN   325147121        1283875     17294          NaN
# 2063  2018        NaN   327167434        1245065     16214          NaN
#
#       rape_revised  robbery  aggravated_assault  property_crime  burglary  \
# ...

# %%
rape_actuals = df.groupby( ['rape_legacy', 'rape_revised'] ).max
condensed_crime_stats
# Out:
#       year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 0     1979        NaN   220099000        1208030     21460      76390.0
# 1     1980        NaN   225349264        1344520     23040      82990.0
# 2     1981        NaN   229465714        1361820     22520      82500.0
# 3     1982        NaN   231664458        1322390     21010      78770.0
# 4     1983        NaN   233791994        1258087     19308      78918.0
# ...    ...        ...         ...            ...       ...          ...
# 2059  2016         WY      584910           1431        20        205.0
# 2060  2017         WY      578934           1358        14          NaN
# 2061  2018         WY      577737           1226        13          NaN
# 2062  2017        NaN   325147121        1283875     17294          NaN
# 2063  2018        NaN   327167434        1245065     16214          NaN
#
#       rape_revised  robbery  aggravated_assault  property_crime  burglary  \
# ...

# %%
year_2015 = df['year']==2015
data_2015 = df[year_2015]   
data_2015 

clean_data = data_2015.drop(columns=["rape_legacy","caveats"]) 
clean_data["state_abbr"].replace('NaN','USA')
clean_data
# Out:
#       year state_abbr  population  violent_crime  homicide  rape_revised  \
# 36    2015        NaN   320896618        1199310     15883      126134.0
# 74    2015         AK      737709           5391        59         900.0
# 114   2015         AL     4853875          22957       348        2037.0
# 154   2015         AR     2977853          15769       189        2008.0
# 194   2015         AZ     6817565          27968       306        3109.0
# 234   2015         CA    38993940         166883      1861       12811.0
# 274   2015         CO     5448819          17348       173        3328.0
# 314   2015         CT     3584730           7938       116         798.0
# 354   2015         DC      670377           8538       162         494.0
# 394   2015         DE      944076           4760        62         361.0
# 434   2015         FL    20244914          93625      1041        7552.0
# 474   2015         GA    10199398          38891       622        3257.0
# ...

# %%
SAT_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1ed51cff67e2> in <module>
# ----> 1 SAT_data
#
# NameError: name 'SAT_data' is not defined
